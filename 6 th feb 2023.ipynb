# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("titanic.csv")
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
# 5            6       0.0       3
# 6            7       0.0       1
# 7            8       0.0       3
# 8            9       1.0       3
# 9           10       1.0       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
#  12  WikiId       1304 non-null   float64
#  13  Name_wiki    1304 non-null   object
#  14  Age_wiki     1302 non-null   float64
#  15  Hometown     1304 non-null   object
#  16  Boarded      1304 non-null   object
#  17  Destination  1304 non-null   object
# ...

# %%
df.Pclass.value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: Pclass, dtype: int64

# %%
Pclass_Survived=df.groupby(['Pclass'])['Survived']
Pclass_Survived

# %%
Pclass_Survived.sum()
# Out:
# Pclass
# 1    136.0
# 2     87.0
# 3    119.0
# Name: Survived, dtype: float64

# %%
Pclass_Survived_fare=df.groupby(['Pclass'])['Survived','Fare']
Pclass_Survived_fare

# %%
Pclass_Survived_fare.sum()
# Out:
#         Survived        Fare
# Pclass
# 1          136.0  28265.4043
# 2           87.0   5866.6374
# 3          119.0   9418.4452

# %%
Pclass_Sex_Survived=df.groupby(['Pclass','Sex'],as_index=False)["Survived"]
Pclass_Sex_Survived

# %%
Pclass_Sex_Survived.sum()
# Out:
#    Pclass     Sex  Survived
# 0       1  female      91.0
# 1       1    male      45.0
# 2       2  female      70.0
# 3       2    male      17.0
# 4       3  female      72.0
# 5       3    male      47.0

# %%
Pclass_Survived=df.groupby(['Pclass','Sex'])['Survived']
Pclass_Survived

# %%
Pclass_Survived.sum()
# Out:
# Pclass  Sex
# 1       female    91.0
#         male      45.0
# 2       female    70.0
#         male      17.0
# 3       female    72.0
#         male      47.0
# Name: Survived, dtype: float64

# %%
bm=df.Survived==0.0

# %%
df[bm].Survived.value_counts()
# Out:
# 0.0    549
# Name: Survived, dtype: int64

# %% [markdown]
# ### num of life boats used

# %%
Pclass_Lifeboat=df.groupby(['Pclass','Lifeboat'])
Pclass_Lifeboat

# %%
Pclass_Lifeboat.value_counts()
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### find hometown  of  > 35

# %%
Pclass_Hometown=df.groupby(['Pclass','Age'])['Hometown']
bm=df.Age==35
df[bm].Hometown.value_counts()
# Out:
# New York, New York, US                4
# Germantown, Pennsylvania, US          2
# Scituate, Massachusetts, US           1
# St Louis, Missouri, US                1
# Hamburg, German Empire[note 2]        1
# Philadelphia, Pennsylvania, US        1
# Kricina, Croatia                      1
# Limerick, Ireland[note 1]             1
# Gumostnik, Lovec, Bulgaria            1
# Landrake, Cornwall, England           1
# Indianapolis, Indiana, US             1
# Broomfield, Essex, England            1
# Birmingham, West Midlands, England    1
# Kyyny, Finland                        1
# Buenos Aires, Argentina               1
# East Providence, Rhode Island, US     1
# London, England, UK                   1
# Liverpool, Merseyside, England, UK    1
# Terry, Mayo, Ireland                  1
# Name: Hometown, dtype: int64

# %%
Pclass_Hometown.value_counts()
# Out:
# Pclass  Age    Hometown
# 1       0.92   Montreal, Quebec, Canada                      1
#         2.00   Montreal, Quebec, Canada                      1
#         4.00   San Francisco, California, US                 1
#         6.00   Tuxedo Park, New York, US                     1
#         11.00  Bryn Mawr, Pennsylvania, US                   1
#                                                             ..
# 3       61.00  Øyer, Norway                                  1
#         63.00  Jalasjärvi, Southern Ostrobothnia, Finland    1
#         65.00  Bunmahon, Waterford, Ireland                  1
#         70.50  Charleville, Cork, Ireland                    1
#         74.00  Reftele, Småland, Sweden                      1
# Name: Hometown, Length: 975, dtype: int64

# %% [markdown]
# ### how many survived from america

# %%
survive_board=df.groupby(['Boarded','Destination'],as_index=False)['Survived']
survive_board.sum()
# Out:
#          Boarded                    Destination  Survived
# 0        Belfast         Brooklyn, New York, US       0.0
# 1        Belfast                  New York City       0.0
# 2        Belfast         New York, New York, US       0.0
# 3      Cherbourg           Albany, New York, US       0.0
# 4      Cherbourg     Brantford, Ontario, Canada       0.0
# ..           ...                            ...       ...
# 335  Southampton     Winnipeg, Manitoba, Canada       4.0
# 336  Southampton  Woodford County, Kentucky, US       1.0
# 337  Southampton   Worcester, Massachusetts, US       3.0
# 338  Southampton          Yonkers, New York, US       0.0
# 339  Southampton           Youngstown, Ohio, US       3.0
#
# [340 rows x 3 columns]

# %%
survive_board=df.groupby(['Boarded','Destination'],as_index=True)['Survived']
survive_board.sum()
# Out:
# Boarded      Destination
# Belfast      Brooklyn, New York, US           0.0
#              New York City                    0.0
#              New York, New York, US           0.0
# Cherbourg    Albany, New York, US             0.0
#              Brantford, Ontario, Canada       0.0
#                                              ...
# Southampton  Winnipeg, Manitoba, Canada       4.0
#              Woodford County, Kentucky, US    1.0
#              Worcester, Massachusetts, US     3.0
#              Yonkers, New York, US            0.0
#              Youngstown, Ohio, US             3.0
# Name: Survived, Length: 340, dtype: float64

# %%
df['cut_method']=pd.cut(df.Age,bins=5,labels=['kid',"children","young","adult","old"])

# %%
df.head(30)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1       0.0       3
# 1             2       1.0       1
# 2             3       1.0       3
# 3             4       1.0       1
# 4             5       0.0       3
# 5             6       0.0       3
# 6             7       0.0       1
# 7             8       0.0       3
# 8             9       1.0       3
# 9            10       1.0       2
# 10           11       1.0       3
# 11           12       1.0       1
# 12           13       0.0       3
# 13           14       0.0       3
# 14           15       0.0       3
# 15           16       1.0       2
# 16           17       0.0       3
# 17           18       1.0       2
# 18           19       0.0       3
# 19           20       1.0       3
# 20           21       0.0       2
# 21           22       1.0       2
# 22           23       1.0       3
# 23           24       1.0       1
# 24           25       0.0       3
# 25           26       1.0       3
# ...

# %%
df.cut_method.value_counts()
# Out:
# children    524
# young       269
# kid         134
# adult       106
# old          13
# Name: cut_method, dtype: int64
